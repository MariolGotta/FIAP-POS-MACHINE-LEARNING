# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

class BookScrapper:
    def __init__(self):
        self.urlbase = 'http://books.toscrape.com/'
        self.catalogue_base = self.urlbase + 'catalogue/'
        self.dados_livros = []

    def get_categorias(self):
        """Coleta os links de todas as categorias disponíveis no site."""
        response = requests.get(self.urlbase)
        soup = BeautifulSoup(response.text, "html.parser")
        categorias = soup.select("ul.nav.nav-list ul li a")
        links = {cat.text.strip(): self.urlbase + cat['href'] for cat in categorias}
        return links

    def get_total_paginas(self, soup):
        """Retorna o número total de páginas de uma categoria."""
        paginacao = soup.select_one("li.current")
        if paginacao:
            match = re.search(r'Page \d+ of (\d+)', paginacao.text.strip())
            return int(match.group(1)) if match else 1
        return 1

    def extrair_livros_pagina(self, soup, categoria):
        """Extrai os dados de cada livro em uma página."""
        livros = soup.select("article.product_pod")

        for livro in livros:
            nome = livro.h3.a["title"]
            preco_raw = livro.select_one(".price_color").text.strip()  # Ex: "£51.77"
            
            # Remover o símbolo "£" e qualquer caractere indesejado
            preco_raw = preco_raw.replace("£", "").strip()
            
            # Garantir que o preço é um número válido
            try:
                preco_num = float(re.sub(r"[^\d.]", "", preco_raw))  # Remover caracteres não numéricos
            except ValueError:
                preco_num = 0.0  # Caso haja erro, atribuir 0.0 ao preço
            
            estrelas = livro.select_one("p.star-rating")["class"][1]  # ex: "Three"
            
            self.dados_livros.append({
                "nome": nome,
                "preco (£)": preco_num,  # Preço em libras sem o símbolo
                "estrelas": estrelas,
                "categoria": categoria
            })

    def processar_categoria(self, categoria_nome, categoria_url):
        """Processa todas as páginas de uma categoria."""
        response = requests.get(categoria_url)
        soup = BeautifulSoup(response.text, "html.parser")
        total_paginas = self.get_total_paginas(soup)

        for pagina in range(1, total_paginas + 1):
            if pagina == 1:
                url_pagina = categoria_url
            else:
                # Substitui "index.html" por "page-X.html" na URL da categoria
                url_pagina = re.sub(r'index\.html$', f'page-{pagina}.html', categoria_url)

            print(f"Baixando: {url_pagina}")
            response = requests.get(url_pagina)
            soup = BeautifulSoup(response.text, "html.parser")
            self.extrair_livros_pagina(soup, categoria_nome)

    def rodar(self):
        """Executa o scraper para todas as categorias."""
        categorias = self.get_categorias()
        for nome, url in categorias.items():
            self.processar_categoria(nome, url)

    def montar_dataframe(self):
        """Monta o DataFrame final com os dados extraídos."""
        df = pd.DataFrame(self.dados_livros)
        return df

# ----------------------------
# EXECUÇÃO
# ----------------------------

if __name__ == "__main__":
    scraper = BookScrapper()
    scraper.rodar()
    df = scraper.montar_dataframe()
# Out:
# Baixando: http://books.toscrape.com/catalogue/category/books/travel_2/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/mystery_3/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/mystery_3/page-2.html
# Baixando: http://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/historical-fiction_4/page-2.html
# Baixando: http://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/sequential-art_5/page-2.html
# Baixando: http://books.toscrape.com/catalogue/category/books/sequential-art_5/page-3.html
# Baixando: http://books.toscrape.com/catalogue/category/books/sequential-art_5/page-4.html
# Baixando: http://books.toscrape.com/catalogue/category/books/classics_6/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/philosophy_7/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/romance_8/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/romance_8/page-2.html
# Baixando: http://books.toscrape.com/catalogue/category/books/womens-fiction_9/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/fiction_10/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/fiction_10/page-2.html
# Baixando: http://books.toscrape.com/catalogue/category/books/fiction_10/page-3.html
# Baixando: http://books.toscrape.com/catalogue/category/books/fiction_10/page-4.html
# Baixando: http://books.toscrape.com/catalogue/category/books/childrens_11/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/childrens_11/page-2.html
# Baixando: http://books.toscrape.com/catalogue/category/books/religion_12/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/nonfiction_13/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/nonfiction_13/page-2.html
# Baixando: http://books.toscrape.com/catalogue/category/books/nonfiction_13/page-3.html
# Baixando: http://books.toscrape.com/catalogue/category/books/nonfiction_13/page-4.html
# Baixando: http://books.toscrape.com/catalogue/category/books/nonfiction_13/page-5.html
# Baixando: http://books.toscrape.com/catalogue/category/books/nonfiction_13/page-6.html
# Baixando: http://books.toscrape.com/catalogue/category/books/music_14/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/default_15/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/default_15/page-2.html
# Baixando: http://books.toscrape.com/catalogue/category/books/default_15/page-3.html
# Baixando: http://books.toscrape.com/catalogue/category/books/default_15/page-4.html
# Baixando: http://books.toscrape.com/catalogue/category/books/default_15/page-5.html
# Baixando: http://books.toscrape.com/catalogue/category/books/default_15/page-6.html
# Baixando: http://books.toscrape.com/catalogue/category/books/default_15/page-7.html
# Baixando: http://books.toscrape.com/catalogue/category/books/default_15/page-8.html
# Baixando: http://books.toscrape.com/catalogue/category/books/science-fiction_16/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/sports-and-games_17/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/add-a-comment_18/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/add-a-comment_18/page-2.html
# Baixando: http://books.toscrape.com/catalogue/category/books/add-a-comment_18/page-3.html
# Baixando: http://books.toscrape.com/catalogue/category/books/add-a-comment_18/page-4.html
# Baixando: http://books.toscrape.com/catalogue/category/books/fantasy_19/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/fantasy_19/page-2.html
# Baixando: http://books.toscrape.com/catalogue/category/books/fantasy_19/page-3.html
# Baixando: http://books.toscrape.com/catalogue/category/books/new-adult_20/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/young-adult_21/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/young-adult_21/page-2.html
# Baixando: http://books.toscrape.com/catalogue/category/books/young-adult_21/page-3.html
# Baixando: http://books.toscrape.com/catalogue/category/books/science_22/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/poetry_23/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/paranormal_24/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/art_25/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/psychology_26/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/autobiography_27/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/parenting_28/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/adult-fiction_29/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/humor_30/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/horror_31/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/history_32/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/food-and-drink_33/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/food-and-drink_33/page-2.html
# Baixando: http://books.toscrape.com/catalogue/category/books/christian-fiction_34/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/business_35/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/biography_36/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/thriller_37/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/contemporary_38/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/spirituality_39/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/academic_40/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/self-help_41/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/historical_42/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/christian_43/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/suspense_44/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/short-stories_45/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/novels_46/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/health_47/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/politics_48/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/cultural_49/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/erotica_50/index.html
# Baixando: http://books.toscrape.com/catalogue/category/books/crime_51/index.html

# %%
print(df)  # Mostra os 5 primeiros livros
print("\nLivros por categoria:")
print(df['categoria'].value_counts())

# Se quiser salvar o DataFrame:
df.to_csv("livros_scrapeados.csv", index=False)
# Out:
#                                                   nome  preco (£) estrelas  \
# 0                              It's Only the Himalayas      45.17      Two
# 1    Full Moon over Noahâs Ark: An Odyssey to Mou...      49.43     Four
# 2    See America: A Celebration of Our National Par...      48.87    Three
# 3    Vagabonding: An Uncommon Guide to the Art of L...      36.94      Two
# 4                                 Under the Tuscan Sun      37.33    Three
# ..                                                 ...        ...      ...
# 995  Why the Right Went Wrong: Conservatism--From G...      52.65     Four
# 996  Equal Is Unfair: America's Misguided Fight Aga...      56.86      One
# 997                                     Amid the Chaos      36.58      One
# 998                                         Dark Notes      19.19     Five
# 999  The Long Shadow of Small Ghosts: Murder and Me...      10.97      One
#
#     categoria
# 0      Travel
# 1      Travel
# 2      Travel
# 3      Travel
# 4      Travel
# ..        ...
# 995  Politics
# 996  Politics
# 997  Cultural
# 998   Erotica
# 999     Crime
#
# [1000 rows x 4 columns]
#
# Livros por categoria:
# categoria
# Default               152
# Nonfiction            110
# Sequential Art         75
# Add a comment          67
# Fiction                65
# Young Adult            54
# Fantasy                48
# Romance                35
# Mystery                32
# Food and Drink         30
# Childrens              29
# Historical Fiction     26
# Classics               19
# Poetry                 19
# History                18
# Womens Fiction         17
# Horror                 17
# Science Fiction        16
# Science                14
# Music                  13
# Business               12
# Travel                 11
# Philosophy             11
# Thriller               11
# Humor                  10
# Autobiography           9
# Art                     8
# Religion                7
# Psychology              7
# Christian Fiction       6
# Spirituality            6
# New Adult               6
# Sports and Games        5
# Biography               5
# Self Help               5
# Health                  4
# Politics                3
# Contemporary            3
# Christian               3
# Historical              2
# Paranormal              1
# Parenting               1
# Adult Fiction           1
# Academic                1
# Short Stories           1
# Suspense                1
# Novels                  1
# Cultural                1
# Erotica                 1
# Crime                   1
# Name: count, dtype: int64

# %%
df.to_csv("livros_scrapeados.csv", index=False)
